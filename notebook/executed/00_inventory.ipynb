# %% [markdown]
# # Assignment 4 (new data) — 0. Inventory of `data/`
#
# **Before any model is trained, establish what is actually on disk.**
#
# The three datasets in `data/` arrive with their own `*_info.md` description files. Those files describe
# what the datasets *are*, not necessarily what was *downloaded*. This notebook trusts neither: it walks the
# directories, counts files, opens images and profiles the CSV, and reports the result.
#
# That distinction is not pedantry. One of the three datasets turns out to be incomplete in a way that makes
# supervised training on it impossible, and it is much cheaper to discover that here than three hours into a
# training run.
#
# | # | Dataset | Declared in `*_info.md` | Model family |
# |---|---------|------------------------|--------------|
# | **A** | CDC BRFSS diabetes 2015+2023 | 546,166 rows × 20 cols, 3 classes | **MLP** |
# | **B** | Rice Image Dataset | 75,000 images, 5 classes | **CNN** |
# | **C** | Intel Image Classification | ~25,000 images, 6 classes | **CNN** — *unusable, see §4* |

# %%
import os, sys, json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0, os.path.abspath("."))        # notebook/  -> ass4_newdata
sys.path.insert(0, os.path.abspath(".."))       # repo root  -> ass4_utils, scratch_nn

import ass4_newdata as D
import ass4_utils as U

plt.rcParams["figure.dpi"] = 110
pd.set_option("display.width", 130)

print("repo root:", D.ROOT)
print("data dir :", D.DATA)
# Out:
# repo root: D:\JupyterNotebooks\ass4
# data dir : D:\JupyterNotebooks\ass4\data

# %% [markdown]
# ---
# ## 1. What is on disk
#
# `D.inventory()` walks every declared directory and counts the image files it really contains. The
# `usable_for_training` column is the one that matters: a split is only usable if it has **class folders**,
# because the folder name *is* the label.

# %%
inv = D.inventory()
display(inv)

print("\ntotal items on disk:", f"{inv['items'].sum():,}")
print("usable for supervised training:",
      f"{inv.loc[inv['usable_for_training'], 'items'].sum():,}")
print("present but unusable (no labels):",
      f"{inv.loc[inv['present'] & ~inv['usable_for_training'], 'items'].sum():,}")
# Out:
#   [OK   ] BRFSS diabetes  diabetes_brfss_2015_2023.csv 546,166 items
#   [OK   ] Rice            Rice_Image_Dataset/Arborio    15,000 items
#   [OK   ] Rice            Rice_Image_Dataset/Basmati    15,000 items
#   [OK   ] Rice            Rice_Image_Dataset/Ipsala     15,000 items
#   [OK   ] Rice            Rice_Image_Dataset/Jasmine    15,000 items
#   [OK   ] Rice            Rice_Image_Dataset/Karacadag  15,000 items
#   [MISS ] Intel scenes    seg_train                          0 items
#   [MISS ] Intel scenes    seg_test                           0 items
#   [MISS ] Intel scenes    seg_pred                           0 items
#           dataset                          part  present   items  labelled  usable_for_training
# 0  BRFSS diabetes  diabetes_brfss_2015_2023.csv     True  546166      True                 True
# 1            Rice    Rice_Image_Dataset/Arborio     True   15000      True                 True
# 2            Rice    Rice_Image_Dataset/Basmati     True   15000      True                 True
# 3            Rice     Rice_Image_Dataset/Ipsala     True   15000      True                 True
# 4            Rice    Rice_Image_Dataset/Jasmine     True   15000      True                 True
# 5            Rice  Rice_Image_Dataset/Karacadag     True   15000      True                 True
# 6    Intel scenes                     seg_train    False       0      True                False
# 7    Intel scenes                      seg_test    False       0      True                False
# 8    Intel scenes                      seg_pred    False       0     False                False
# total items on disk: 621,166
# usable for supervised training: 621,166
# present but unusable (no labels): 0

# %% [markdown]
# > ### Finding: the Intel dataset is incomplete
# >
# > `data/` contains `seg_pred/` — 7,301 loose `.jpg` files with **no class sub-folders** — but neither
# > `seg_train/` nor `seg_test/`. `seg_pred` is the original competition's *prediction* set: it never had
# > public labels. Without `seg_train`/`seg_test` there is no ground truth, so on this dataset it is
# > impossible to train a classifier, and equally impossible to measure an accuracy.
# >
# > **MNIST takes its place.** Rather than report numbers from data that cannot support them, the third
# > image slot is filled by MNIST in `03_mnist_cnn.ipynb`, downloaded automatically by `torchvision`.
# > That keeps the assignment's shape intact — one tabular dataset, two image datasets, three
# > implementations each — and adds something the Intel data could not have offered: the repository root
# > already ran MNIST with the same architecture in `02_mnist.ipynb`, so the new run doubles as a
# > reproduction check. `D.require_intel_labels()` remains available, so restoring `seg_train`/`seg_test`
# > is all that is needed to revisit the scene data.

# %% [markdown]
# ---
# ## 2. Dataset A — BRFSS diabetes (tabular)
#
# The claims in `data/diabetes_info.md` that the notebooks depend on are checked here directly: the row
# count, the absence of missing values, the class split, and the 2015/2023 balance.

# %%
df = pd.read_csv(D.DIABETES_CSV)

print(f"shape            {df.shape}")
print(f"missing values   {int(df.isna().sum().sum())}")
print(f"duplicate rows   {int(df.duplicated().sum()):,}  (kept on purpose - see info file)")
print(f"memory           {df.memory_usage(deep=True).sum() / 1e6:.1f} MB")

display(df.head())
display(df.describe().T[["min", "max", "mean", "std"]].round(2))
# Out:
# shape            (546166, 20)
# missing values   0
# duplicate rows   67,731  (kept on purpose - see info file)
# memory           87.4 MB
#    year  Diabetes_012  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  HeartDiseaseorAttack  PhysActivity  AnyHealthcare  \
# 0  2015             0       1         1          1  40.0       1       0                     0             0              1
# 1  2015             0       0         0          0  25.0       1       0                     0             1              0
# 2  2015             0       1         1          1  28.0       0       0                     0             0              1
# 3  2015             0       1         0          1  27.0       0       0                     0             1              1
# 4  2015             0       1         1          1  24.0       0       0                     0             1              1
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# 0            0        5        18        15         1    0    9          2       2
# 1            1        3         0         0         0    0    7          4       1
# 2            1        5        30        30         1    0    9          2       5
# 3            0        2         0         0         0    0   11          1       4
# 4            0        2         3         0         0    0   11          3       2
#                          min      max     mean   std
# year                  2015.0  2023.00  2018.91  4.00
# Diabetes_012             0.0     2.00     0.31  0.71
# HighBP                   0.0     1.00     0.43  0.50
# HighChol                 0.0     1.00     0.42  0.49
# CholCheck                0.0     1.00     0.96  0.19
# BMI                     12.0    99.82    28.60  6.57
# Smoker                   0.0     1.00     0.42  0.49
# Stroke                   0.0     1.00     0.04  0.20
# HeartDiseaseorAttack     0.0     1.00     0.09  0.29
# PhysActivity             0.0     1.00     0.77  0.42
# AnyHealthcare            0.0     1.00     0.96  0.20
# NoDocbcCost              0.0     1.00     0.08  0.27
# GenHlth                  1.0     5.00     2.54  1.05
# MentHlth                 0.0    30.00     3.68  7.76
# PhysHlth                 0.0    30.00     4.32  8.71
# DiffWalk                 0.0     1.00     0.16  0.37
# Sex                      0.0     1.00     0.46  0.50
# Age                      1.0    13.00     8.01  3.19
# Education                1.0     4.00     3.12  0.93
# Income                   1.0     5.00     4.06  1.31

# %%
# Target balance overall and per survey year - the imbalance drives how the
# results in notebook 01 have to be read.
counts = df[D.BRFSS_TARGET].value_counts().sort_index()
by_year = pd.crosstab(df["year"], df[D.BRFSS_TARGET], normalize="index")
by_year.columns = D.BRFSS_CLASSES

fig, ax = plt.subplots(1, 2, figsize=(11, 3.6))
bars = ax[0].bar(D.BRFSS_CLASSES, counts.values, color=["#4C78A8", "#F58518", "#E45756"])
ax[0].set_title("Target balance (Diabetes_012)")
ax[0].set_ylabel("respondents")
for b, c in zip(bars, counts.values):
    ax[0].text(b.get_x() + b.get_width() / 2, c, f"{c:,}\n{c / counts.sum():.1%}",
               ha="center", va="bottom", fontsize=8)

by_year.plot(kind="bar", stacked=True, ax=ax[1],
             color=["#4C78A8", "#F58518", "#E45756"])
ax[1].set_title("Class share by survey year")
ax[1].set_ylabel("share"); ax[1].tick_params(axis="x", rotation=0)
ax[1].legend(fontsize=7)
fig.tight_layout(); plt.show()

display((by_year * 100).round(2))
print("\nRows per year:"); print(df["year"].value_counts().sort_index().to_string())
# Out:
#       no diabetes  prediabetes  diabetes
# year
# 2015        84.24         1.83     13.93
# 2023        82.89         2.51     14.60
# Rows per year:
# year
# 2015    279048
# 2023    267118

# %% [markdown]
# The two survey years agree closely on every prevalence, which is the evidence that merging them vertically
# was legitimate. The class split is roughly **84 / 2 / 14**, and `prediabetes` is rare enough that accuracy
# alone will be a misleading score — the point `theory_notes.md` §4.2 makes about the original diabetes data.

# %% [markdown]
# ---
# ## 3. Dataset B — Rice images
#
# 75,000 JPEGs in five class folders. What matters for the loader is that every image really is the same
# size and colour mode, because the CNN legs assume a fixed tensor shape.

# %%
rice_counts = {c: D._count_images(os.path.join(D.RICE_DIR, c)) for c in D.RICE_CLASSES}
print("images per class:")
for c, n in rice_counts.items():
    print(f"  {c:<12}{n:>8,}")
print(f"  {'TOTAL':<12}{sum(rice_counts.values()):>8,}")
print(f"\nperfectly balanced: {len(set(rice_counts.values())) == 1}")

# Verify the declared 250x250 RGB on a random sample rather than assuming it.
from PIL import Image
rng = np.random.default_rng(U.SEED)
sizes, modes = {}, {}
for c in D.RICE_CLASSES:
    folder = os.path.join(D.RICE_DIR, c)
    files = sorted(os.listdir(folder))
    for f in rng.choice(files, size=60, replace=False):
        with Image.open(os.path.join(folder, f)) as im:
            sizes[im.size] = sizes.get(im.size, 0) + 1
            modes[im.mode] = modes.get(im.mode, 0) + 1
print("\nsampled 300 images ->")
print("  sizes:", sizes)
print("  modes:", modes)
# Out:
# images per class:
#   Arborio       15,000
#   Basmati       15,000
#   Ipsala        15,000
#   Jasmine       15,000
#   Karacadag     15,000
#   TOTAL         75,000
#
# perfectly balanced: True
# sampled 300 images ->
#   sizes: {(250, 250): 300}
#   modes: {'RGB': 300}

# %%
# One example per class at native resolution, then the same grain at the 32x32
# the CNN notebooks actually train on.
fig, axes = plt.subplots(2, len(D.RICE_CLASSES), figsize=(13, 5.4))
for j, c in enumerate(D.RICE_CLASSES):
    folder = os.path.join(D.RICE_DIR, c)
    f = sorted(os.listdir(folder))[0]
    with Image.open(os.path.join(folder, f)) as im:
        im = im.convert("RGB")
        axes[0, j].imshow(im)
        axes[1, j].imshow(im.resize((32, 32), Image.BILINEAR))
    axes[0, j].set_title(c, fontsize=10)
    for i in (0, 1):
        axes[i, j].axis("off")
axes[0, 0].set_ylabel("250x250"); axes[1, 0].set_ylabel("32x32")
fig.suptitle("Rice grains: native resolution (top) and the 32x32 training input (bottom)")
fig.tight_layout(); plt.show()

# %% [markdown]
# **Why 32×32 is enough here.** What separates the five varieties is grain *shape*, *size* and *colour* —
# Basmati is long and slender, Arborio short and round. Those survive aggressive downsampling, as the bottom
# row shows. Each image is one centred grain on a black background, so there is no clutter to resolve and no
# segmentation step needed. 32×32 also makes the full 75,000-image set fit comfortably in memory as float32
# (~0.9 GB) and keeps the NumPy-from-scratch leg tractable, which a 250×250 input would not.

# %% [markdown]
# ---
# ## 4. Dataset C — Intel scenes
#
# This is where the inventory pays for itself.

# %%
for label, base in [("seg_train", D.INTEL_TRAIN_DIR), ("seg_test", D.INTEL_TEST_DIR)]:
    root = D._intel_root(base, label)
    exists = os.path.isdir(base)
    per_class = {c: D._count_images(os.path.join(root, c)) for c in D.INTEL_CLASSES}
    print(f"{label:<10} directory exists: {str(exists):<5}  labelled images: {sum(per_class.values()):,}")

pred_root = D._intel_root(D.INTEL_PRED_DIR, "seg_pred")
pred_files = [f for f in os.listdir(pred_root) if f.lower().endswith(".jpg")]
subdirs = [d for d in os.listdir(pred_root) if os.path.isdir(os.path.join(pred_root, d))]
print(f"\nseg_pred   {len(pred_files):,} jpg files, {len(subdirs)} sub-directories")
print("-> flat file list, no class folders, therefore NO LABELS")
# Out:
# seg_train  directory exists: False  labelled images: 0
# seg_test   directory exists: False  labelled images: 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       4     per_class = {c: D._count_images(os.path.join(root, c)) for c in D.INTEL_CLASSES}
#       5     print(f"{label:<10} directory exists: {str(exists):<5}  labelled images: {sum(per_class.values()):,}")
#       6
#       7 pred_root = D._intel_root(D.INTEL_PRED_DIR, "seg_pred")
# ----> 8 pred_files = [f for f in os.listdir(pred_root) if f.lower().endswith(".jpg")]
#       9 subdirs = [d for d in os.listdir(pred_root) if os.path.isdir(os.path.join(pred_root, d))]
#      10 print(f"\nseg_pred   {len(pred_files):,} jpg files, {len(subdirs)} sub-directories")
#      11 print("-> flat file list, no class folders, therefore NO LABELS")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\JupyterNotebooks\\ass4\\data\\seg_pred'

# %%
# Confirm the guard fires with an actionable message instead of a late crash.
try:
    D.load_intel_scene()
    print("labelled splits found - the scene data could be used after all")
except FileNotFoundError as e:
    print("GUARD FIRED as expected:\n")
    print(e)
# Out:
# GUARD FIRED as expected:
#
# Intel Image Classification is incomplete in data/.
#   missing labelled split(s): seg_train, seg_test
#   present: seg_pred (0 images, no labels)
#
# seg_pred is the competition's prediction set: flat files, no class
# folders, no ground truth. It can be used for an inference demo but
# not for training or for measuring accuracy.
#
# To complete the dataset:
#   pip install kaggle
#   kaggle datasets download -d puneet6060/intel-image-classification \
#       -p data/ --unzip
# which restores data/seg_train/ and data/seg_test/.

# %%
# seg_pred is still real imagery and is usable for an unlabelled demo.
X_pred, names = D.load_intel_unlabeled(img_size=64, n=10)
fig, axes = plt.subplots(1, 10, figsize=(15, 1.9))
for ax, img, nm in zip(axes, X_pred, names):
    ax.imshow(img.transpose(1, 2, 0)); ax.set_title(nm, fontsize=6); ax.axis("off")
fig.suptitle("seg_pred — real scenes, but no ground-truth class for any of them")
fig.tight_layout(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # seg_pred is still real imagery and is usable for an unlabelled demo.
# ----> 2 X_pred, names = D.load_intel_unlabeled(img_size=64, n=10)
#       3 fig, axes = plt.subplots(1, 10, figsize=(15, 1.9))
#       4 for ax, img, nm in zip(axes, X_pred, names):
#       5     ax.imshow(img.transpose(1, 2, 0)); ax.set_title(nm, fontsize=6); ax.axis("off")
#
# File D:\JupyterNotebooks\ass4\notebook\ass4_newdata.py:534, in load_intel_unlabeled(img_size, n, seed, verbose)
#     527 """Load images from `seg_pred` for an inference demo. Returns X only.
#     528
#     529 There are no labels here by construction, so this deliberately returns a
#     530 single array - there is nothing to score against.
#     531 """
#     532 root = _intel_root(INTEL_PRED_DIR, "seg_pred")
#     533 files = sorted(
# --> 534     f for f in os.listdir(root)
#     535     if f.lower().endswith((".jpg", ".jpeg", ".png"))
#     536 )
#     537 if not files:
#     538     raise FileNotFoundError(f"no images under {root}")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\JupyterNotebooks\\ass4\\data\\seg_pred'

# %% [markdown]
# ---
# ## 5. The stand-in — MNIST
#
# MNIST is not in `data/`, and does not need to be: `ass4_utils.load_mnist` fetches it through `torchvision`
# on first call (about 12 MB) into `data/mnist/`. The cell below is the only check worth making here — that
# the download works and the arrays arrive in the shape the notebooks expect.
#
# It is a deliberate choice of substitute. MNIST differs from the rice images in every way that matters for
# the comparison — **greyscale rather than RGB, ten classes rather than five, handwriting rather than
# photography** — so the collection still covers two genuinely different image problems. And because
# `02_mnist.ipynb` in the repository root already ran this architecture, notebook 03 can check its own
# numbers against a committed result.

# %%
try:
    Xm, ym, Xmt, ymt, mmeta = U.load_mnist(n_train=2_000, n_test=500)
    print(f"shape {mmeta['shape']}  classes {len(mmeta['classes'])}  dtype {Xm.dtype}")
    print(f"per-class counts (2k sample): {np.bincount(ym)}")
    U.plot_samples(Xm, ym, mmeta["classes"], n=12,
                   title="MNIST - the stand-in for the Intel scene data")
    plt.show()
except Exception as e:
    print("MNIST download failed:", type(e).__name__, e)
    print("torchvision fetches it on first use; check the network connection.")
# Out:
# MNIST: train (2000, 1, 28, 28) / test (500, 1, 28, 28), 10 classes
# shape (1, 28, 28)  classes 10  dtype float32
# per-class counts (2k sample): [184 219 204 214 190 177 189 222 208 193]

# %% [markdown]
# ---
# ## 6. Verdict

# %%
verdict = pd.DataFrame([
    ["A  BRFSS diabetes", "tabular", "546,166 rows x 19 features", "3", "YES",
     "01_diabetes_brfss.ipynb"],
    ["B  Rice images",    "image",   "75,000 x 250x250 RGB",       "5", "YES",
     "02_rice_cnn.ipynb"],
    ["C  Intel scenes",   "image",   "7,301 unlabelled only",      "6", "NO - labels missing",
     "-- replaced by MNIST --"],
    ["C' MNIST (stand-in)", "image", "70,000 x 28x28 greyscale",   "10", "YES (auto-download)",
     "03_mnist_cnn.ipynb"],
], columns=["dataset", "kind", "usable material", "classes", "trainable?", "notebook"])
display(verdict)
# Out:
#                dataset     kind             usable material classes           trainable?                 notebook
# 0    A  BRFSS diabetes  tabular  546,166 rows x 19 features       3                  YES  01_diabetes_brfss.ipynb
# 1       B  Rice images    image        75,000 x 250x250 RGB       5                  YES        02_rice_cnn.ipynb
# 2      C  Intel scenes    image       7,301 unlabelled only       6  NO - labels missing  -- replaced by MNIST --
# 3  C' MNIST (stand-in)    image    70,000 x 28x28 greyscale      10  YES (auto-download)       03_mnist_cnn.ipynb

# %% [markdown]
# **Three datasets can be trained on; the Intel scene data cannot.**
#
# - **BRFSS diabetes** and **Rice** are complete and go straight into notebooks 01 and 02. Between them they
#   cover both halves of the assignment's argument: a tabular problem where convolution has nothing to
#   exploit, and an image problem where it does.
# - **Intel scenes** contributes no number to any results table. `seg_pred` has no labels, so nothing can be
#   trained on it and nothing can be scored against it. To revisit it later, restore the labelled splits with
#   `kaggle datasets download -d puneet6060/intel-image-classification -p data/ --unzip`; the loaders
#   (`D.load_intel_scene`, `D.require_intel_labels`) are still in `ass4_newdata.py` and ready.
# - **MNIST stands in** as the second image dataset, in `03_mnist_cnn.ipynb`. It is fetched by `torchvision`
#   on first run, so nothing needs copying into `data/` by hand.
#
# Notebook 04 then runs the M1→M4 improvement ladder from `theory_notes.md` §3, and notebook 05 collects
# everything into the cross-dataset comparison.
